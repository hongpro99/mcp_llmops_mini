# %%
# quick_check.py
from backend.settings import settings
print("repr(DATABASE_URL) =", repr(getattr(settings, "DATABASE_URL", None)))
# Out:
# repr(DATABASE_URL) = 'postgresql+psycopg2://postgres:postgres@localhost:5432/ragdb'
